# %% [markdown]
# # PRODIGY_DS_05
#
# Task:5 Analyse Traffic accident data to identify patterns related to road conditions,weather and time of day.Visualize accidents hotspots and contributing factors.
#
# Tool Used : Power BI
#
# Data Cleaning: The dataset is cleaned using Power Query feature of Power BI. It helps to clean and transform the data.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Data Visualizations:
#
#
#
#
# *   Metropolitan Police force having highest reported accidents.
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   westminster having highest reported accidents
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   MotorCycle isthe vehicle causing highest number of accidents
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Dry road and wet and damp surface affecting the accident severity
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *  Slight causes more number of casualities
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   T-Junction is the place where number of caasualities are more.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Dashboard:
#
#
#
#
# ![image.png](data:image/png;base64,...)
